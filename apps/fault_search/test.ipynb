# %%
from datetime import datetime

# %%
memoryname=datetime.now().strftime("%Y%m%d%H%M%S")+".md"
print(memoryname)
# Out:
# 20260621211440.md

# %%
import os
memory_demo_path=os.getcwd()+r"/fault_search/fault_search.py"
f=open(memory_demo_path,"r")

# %%
import os
print(os.getcwd())
# Out:
# E:\IDEA_bench\troubleshooting_agent
